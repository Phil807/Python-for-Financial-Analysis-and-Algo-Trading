# %%
import pandas as pd

# %%
df = pd.read_excel('Timetable Semester 2.xlsx')

# %%
df
# Out:
#                                     Monday Unnamed: 1                Tuesday  \
# Time                                Module       Room                 Module
# 9     Treasury and Risk Management (Jimmy)       Q005                    NaN
# 10    Treasury and Risk Management (Jimmy)       Q005                    NaN
# 11         International Money and Banking   TH.Q Art  Contempory OB (3/5/7)
# 12                                     NaN        NaN  Contempory OB (3/5/7)
# 13                                     NaN        NaN                    NaN
# 14                        Linear Algebra 1   G108 Art                    NaN
# 15                                     NaN        NaN                    NaN
# 16                                     NaN        NaN                    NaN
#
#      Unnamed: 3                        Wednesday Unnamed: 5  \
# Time       Room                           Module       Room
# 9           NaN                              NaN        NaN
# ...
