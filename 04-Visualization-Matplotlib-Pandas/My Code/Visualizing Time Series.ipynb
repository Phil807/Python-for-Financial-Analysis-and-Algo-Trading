# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#using notebook instead of inline makes the plots interactive

# %%
# %matplotlib notebook

# %%
mcdon = pd.read_csv('mcdonalds.csv', index_col = 'Date', parse_dates= True)

# %%
mcdon.head()
# Out:
#             Adj. Close  Adj. Volume
# Date
# 1970-01-02    0.209761    2825604.0
# 1970-01-05    0.213316    2210449.5
# 1970-01-06    0.214501    1951168.5
# 1970-01-07    0.213316    2728768.5
# 1970-01-08    0.213316    2242404.0

# %%
mcdon['Adj. Close'].plot()
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
mcdon['Adj. Volume'].plot()

# %%
mcdon['Adj. Volume'].plot(figsize=(12,4))

# %%
mcdon['Adj. Close'].plot(xlim=['2007-01-01','2009-01-01'], ylim=(20,60)) 

#notice I am calling .plot() a matplotlib method straight of the pandas dataframe

# %%
mcdon['Adj. Close'].plot(xlim=['2007-01-01','2009-01-01'], ylim=(20,60), ls='--', c='r')

# %%
#the time series should pretty much always be on the x axis
#if the default x axis doesnt work for us then can use matplotlib.dates module to change it

# %%
import matplotlib.dates as dates  #can also write from matplotlib import dates

# %%
mcdon['Adj. Close'].plot(xlim=['2007-01-01','2009-01-01'], ylim=(0,50))

# %%
idx = mcdon.loc['2007-01-01':'2007-05-01'].index

# %%
idx
# Out:
# DatetimeIndex(['2007-01-03', '2007-01-04', '2007-01-05', '2007-01-08',
#                '2007-01-09', '2007-01-10', '2007-01-11', '2007-01-12',
#                '2007-01-16', '2007-01-17', '2007-01-18', '2007-01-19',
#                '2007-01-22', '2007-01-23', '2007-01-24', '2007-01-25',
#                '2007-01-26', '2007-01-29', '2007-01-30', '2007-01-31',
#                '2007-02-01', '2007-02-02', '2007-02-05', '2007-02-06',
#                '2007-02-07', '2007-02-08', '2007-02-09', '2007-02-12',
#                '2007-02-13', '2007-02-14', '2007-02-15', '2007-02-16',
#                '2007-02-20', '2007-02-21', '2007-02-22', '2007-02-23',
#                '2007-02-26', '2007-02-27', '2007-02-28', '2007-03-01',
#                '2007-03-02', '2007-03-05', '2007-03-06', '2007-03-07',
#                '2007-03-08', '2007-03-09', '2007-03-12', '2007-03-13',
#                '2007-03-14', '2007-03-15', '2007-03-16', '2007-03-19',
# ...

# %%
stock = mcdon.loc['2007-01-01':'2007-05-01']['Adj. Close']

# %%
stock.head()
# Out:
# Date
# 2007-01-03    31.662754
# 2007-01-04    31.424580
# 2007-01-05    31.424580
# 2007-01-08    31.547276
# 2007-01-09    31.605015
# Name: Adj. Close, dtype: float64

# %%
#now lets plot on matplotlib

# %%
fig, ax = plt.subplots()

ax.plot_date(idx,stock,'-')        #plot_date method called off ax lets matplotlib know that we 
ax.yaxis.grid(True)                 #are dealing with a datetime index array
ax.xaxis.grid(True)                 #this lets matplotlib know we can call things like year, month, week and day off of it

fig.autofmt_xdate()                 #automatically formats the x date axis

#LOCATING AND FORMATTING THE AXIS

#Locating
ax.xaxis.set_major_locator(dates.MonthLocator())  #locates the month tick on the x axis

#Formatting
ax.xaxis.set_major_formatter(dates.DateFormatter('\n\n\n%b--%Y'))  



#CAN ALSO INTRODUCE A MINOR X AXIS

#Locating
ax.xaxis.set_minor_locator(dates.WeekdayLocator(byweekday=0)) #byweekday chooses what weekday to locate, 0 is Monday

#Formatting
ax.xaxis.set_minor_formatter(dates.DateFormatter('%d'))
# Out:
# <img src="data:image/png;base64,..." width="640">
